# %% [markdown]
# # MISO

# %%
import urllib.request, json
import pandas as pd
from datetime import datetime, date, timedelta
import time
import sys, os
from IPython.display import display
import numpy as np
import wget
import urllib
import warnings
import requests


start_time = input('Enter the start time(YYYY-MM-DD): ')
if len(start_time) < 1:
    start_time = '2025-01-01'

end_time = input('Enter the end time(YYYY-MM-DD): ')
if len(end_time) < 1:
    end_time = '2025-01-02'

variable_name = input('Enter the Variable name: ')
if len(variable_name) < 1:
    variable_name = 'demand_forecast_hourly_regional_MISO'

info_dict_MISO = {
    'solar_forecast_hourly_MISO':{'variable_str':'_mom.xlsx','variable_date_str':'SOLAR HOURLY'},
    'wind_forecast_hourly_MISO':{'variable_str':'_mom.xlsx','variable_date_str':'WIND HOURLY'},
    'outage_forecast_daily_MISO':{'variable_str':'_mom.xlsx','variable_date_str':'OUTAGE'},
    'demand_forecast_hourly_zone_MISO':{'variable_str':'df_al.xls','variable_date_str':'n/a'},
    'demand_forecast_hourly_regional_MISO':{'variable_str':'rf_al.xls','variable_date_str':'n/a'},
    'DA_LMP_MISO':{'variable_str':'da_exante_lmp.csv','variable_date_str':'n/a'},# Miso will change it to New API
    'RT_LMP_MISO':{'variable_str':'5min_exante_lmp.xlsx','variable_date_str':'n/a'},# Miso will change it to New API
    'DA_HUB_price_MISO': {'variable_str': 'da_pr.xls','variable_date_str':'n/a'},
    'RT_HUB_price_MISO': {'variable_str': 'rt_pr.xls','variable_date_str':'n/a'},
    }

def date_range_list(start_date, end_date):
    # Return generator for a list datetime.date objects (inclusive) between start_date and end_date (inclusive).
    curr_date = start_date
    while curr_date <= end_date:
        yield curr_date 
        curr_date += timedelta(days=1)


def miso_data_downloading(start_time, end_time, variable_name, info_dict_MISO):
    start_time_list = start_time.split('-')
    end_time_list = end_time.split('-')

    d0 = date(int(start_time_list[0]), int(start_time_list[1]), int(start_time_list[2]))
    d1 = date(int(end_time_list[0]), int(end_time_list[1]), int(end_time_list[2]))
    data_array = []
    date_list = date_range_list(d0, d1)

    variable_str = info_dict_MISO[variable_name]['variable_str']
    variable_date_str = info_dict_MISO[variable_name]['variable_date_str']
    
    ###
    # variable_name=='DA_HUB_price_MISO' or variable_name=='RT_LMP_MISO'
    ###
    if variable_name=='DA_HUB_price_MISO' or variable_name=='RT_LMP_MISO':
        for day in date_list:
            date_list = str(day).split('-')
            YYYYMMDD = date_list[0]+date_list[1]+date_list[2]
            url = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD +'_' + variable_str

            df_0 = pd.read_excel(url, index_col=None,na_values=['NA'], usecols="B")
            #print(df_0)
            header_num = 0
            header = 0
            Header_str = 'NaN'
            while Header_str != 'MISO System':
                Header_str = str(df_0.iloc[header,0])
                header = header_num
                header_num = header_num + 1
                if header > len(df_0['Unnamed: 1']):
                    break
            #print(header)
            df = pd.read_excel(io = url,index_col= None , na_values=['NA'], header=header, nrows = 24)#, usecols=["B","C","D","E","F","G","H","I","J"]
            print(df)
            if str(day) == str(start_time):
                sum_df = df
            else:
                sum_df = pd.concat([sum_df, df], ignore_index = True)

    
    
    ###
    # elif (variable_name == 'solar_forecast_hourly_MISO' or variable_name == 'wind_forecast_hourly_MISO' or variable_name == 'outage_forecast_daily_MISO')
    ###
    elif (variable_name == 'solar_forecast_hourly_MISO' or variable_name == 'wind_forecast_hourly_MISO' 
          or variable_name == 'outage_forecast_daily_MISO'):
        i = 0
        for day in date_list:
            date_str = str(day).split('-')
            YYYYMMDD = date_str[0]+date_str[1]+date_str[2]
            current_date = day + timedelta(days = 1)
            current_date_str = str(current_date).split('-')
            
            url_2 = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD + '_'+variable_str
            print(YYYYMMDD)
            header = 0
            try:
                df = pd.read_excel(url_2, index_col=None, sheet_name=variable_date_str,na_values=['NA'], usecols="A")
                header_num = 0
                header = 0
                Header_str = 'NaN'
                while Header_str != 'DAY HE' and Header_str != 'Day HE':#or Header_str != 'Day HE'
                    Header_str = str(df.iloc[header,0])
                    header = header_num
                    header_num = header_num + 1
                    if header > len(df['Unnamed: 0']):
                        break
                df_mom = pd.read_excel(io = url_2,index_col= None , na_values=['NA'], header=header, usecols='A,B,C,D',#,D
                                     sheet_name=variable_date_str,nrows = 48,engine="openpyxl")
                time_info = 'NaN'
                time_info_1am = current_date_str[1] + '/'+ current_date_str[2] + '/' + current_date_str[0] + ' 1'
                time_info_7am = current_date_str[1] + '/'+ current_date_str[2] + '/' + current_date_str[0] + ' 7'
                
                time_idx = 0
                while time_info != time_info_1am:
                    time_info = str(''.join(list(df_mom.iloc[time_idx,0])[2:15]))
                    time_idx = time_idx + 1
                    #if time_info = 
                    if time_idx > len(df_mom.iloc[:,0]):
                        break
                iloc_start = time_idx - 1
                iloc_end = iloc_start+24
                
                
                df_mom = df_mom.iloc[iloc_start:iloc_end,:]
                data_array.append(1)
            except:
                try:
                    df = pd.read_excel(url_1, index_col=None, sheet_name=variable_date_str,na_values=['NA'], usecols="A")
                    header_num = 0
                    header = 0
                    Header_str = 'NaN'
                    while Header_str != 'DAY HE'and Header_str != 'Day HE':#or Header_str != 'Day HE'
                        Header_str = str(df.iloc[header,0])
                        header = header_num
                        header_num = header_num + 1
                        if header > len(df['Unnamed: 0']):
                            break
        
                    df_mom = pd.read_excel(io = url_1,index_col= None , na_values=['NA'], header=header, usecols='A,B,C,D',#,D
                                     sheet_name=variable_date_str,nrows = 168,engine="openpyxl")
                    time_info = 'NaN'
                    time_info_1am = current_date_str[1] + '/'+ current_date_str[2] + '/' + current_date_str[0] + ' 1'
                    time_info_7am = current_date_str[1] + '/'+ current_date_str[2] + '/' + current_date_str[0] + ' 7'
        
                    time_idx = 0
                    while time_info != time_info_1am:
                        time_info = str(''.join(list(df_mom.iloc[time_idx,0])[2:15]))
                        time_idx = time_idx + 1
                        if time_idx > len(df_mom.iloc[:,0]):
                            break
                    iloc_start = time_idx - 1
                    iloc_end = iloc_start+24
        
                    df_mom = df_mom.iloc[iloc_start:iloc_end,:]
                    data_array.append(2)
            
                except:
                    intial_date = date(int(date_str[0]), int(date_str[1]), int(date_str[2]))
                    day_i = 0
                    #day_i = day_i + 1
                    file_date = intial_date + timedelta(days = -day_i)
                    file_date_str = str(file_date).split('-')
                    YYYYMMDD_1 = file_date_str[0]+file_date_str[1]+file_date_str[2]
                    url_try = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD_1 + variable_str
        
                    response = requests.get(url_try)
                    while response.status_code != 200:
                        file_date = intial_date + timedelta(days = -day_i)
                        file_date_str = str(file_date).split('-')
                        YYYYMMDD_1 = file_date_str[0]+file_date_str[1]+file_date_str[2]
                        url_try = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD_1 + variable_str
                        response = requests.get(url_try)
                        day_i = day_i + 1
                        print("Found previous: ", YYYYMMDD_1)
                    #url_1_1 = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD + '_mom.xlsx'
                    df = pd.read_excel(url_try, index_col=None, sheet_name='WIND HOURLY',na_values=['NA'], usecols="A")
                    header_num = 0
                    header = 0
                    Header_str = 'NaN'
                    while Header_str != 'DAY HE'and Header_str != 'Day HE':#or Header_str != 'Day HE'
                        Header_str = str(df.iloc[header,0])
                        header = header_num
                        header_num = header_num + 1
                        if header > len(df['Unnamed: 0']):
                            break
        
                    df_mom = pd.read_excel(io = url_try,index_col= None , na_values=['NA'], header=header, usecols='A,B,C,D',#,D
                                     sheet_name='WIND HOURLY',nrows = 168,engine="openpyxl")
                    time_info = 'NaN'
                    time_info_1am = current_date_str[1] + '/'+ current_date_str[2] + '/' + current_date_str[0] + ' 1'
                    time_info_7am = current_date_str[1] + '/'+ current_date_str[2] + '/' + current_date_str[0] + ' 7'
        
                    time_idx = 0
                    while time_info != time_info_1am:
                        time_info = str(''.join(list(df_mom.iloc[time_idx,0])[2:15]))
                        time_idx = time_idx + 1
                        if time_idx > len(df_mom.iloc[:,0]):
                            break
                    iloc_start = time_idx - 1
                    iloc_end = iloc_start+24
        
                    df_mom = df_mom.iloc[iloc_start:iloc_end,:]
                    data_array.append(2)
                if Header_str == 'Day HE':
                    df_mom = df_mom.rename(columns={'Day HE': 'DAY HE', 'North': 'North','Central': 'Central'})
            
            if str(day) == str(start_time):
                sum_df = df_mom
            else:
                sum_df = pd.concat([sum_df, df_mom], ignore_index = False)#, ignore_index = True
            url_1 = url_2
            i = i + 1
    ###
    # elif (variable_name == 'outage_forecast_daily_MISO')
    ###
    elif (variable_name == 'outage_forecast_daily_MISO'):
        i = 0
        for day in date_list:
            date_str = str(day).split('-')
            YYYYMMDD = date_str[0]+date_str[1]+date_str[2]
            current_date = day + timedelta(days = 1)
            current_date_str = str(current_date).split('-')
            
            url_2 = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD + '_' + variable_str
            print(YYYYMMDD)
            header = 0
            try:
                #df = pd.read_excel(url_2, index_col=None, sheet_name='OUTAGE',na_values=['NA'], usecols="C")
                #header_num = 0
                header = 6
                index_day = 2
                df_outage = pd.read_excel(io = url_2,index_col= None , na_values=['NA'], header=header, usecols='A,B,C',#,D
                                     sheet_name=variable_date_str,nrows = 16,engine="openpyxl")
                
                sum_north = df_outage[df_outage["Unnamed: 0"]=="North"].sum()
                sum_central = df_outage[df_outage["Unnamed: 0"]=="Central"].sum()
                sum_south = df_outage[df_outage["Unnamed: 0"]=="South"].sum()
                sum_miso = df_outage[df_outage["Unnamed: 0"]=="MISO"].sum()
                df_sum_data_day =  pd.DataFrame({'Outage_North': [sum_north.iloc[index_day]],'Outage_Central': [sum_central.iloc[index_day]],
                               'Outage_South': [sum_south.iloc[index_day]],'Outage_MISO': [sum_miso.iloc[index_day]]})
                df_outage_sum = pd.DataFrame()
                for i_hour in range(24):
                    df_outage_sum = pd.concat([df_sum_data_day, df_outage_sum], ignore_index = False)
                
                data_array.append(1)
            except:
                try:
                    #df = pd.read_excel(url_1, index_col=None, sheet_name='SOLAR HOURLY',na_values=['NA'], usecols="A,B,C,D")
                    header_num = 0
                    header = 6
                    
                    df_outage = pd.read_excel(io = url_1,index_col= None , na_values=['NA'], header=header, usecols='A,B,C,D',#,D
                                     sheet_name=variable_date_str,nrows = 16,engine="openpyxl")
                    index_day = 3
                    sum_north = df_outage[df_outage["Unnamed: 0"]=="North"].sum()
                    sum_central = df_outage[df_outage["Unnamed: 0"]=="Central"].sum()
                    sum_south = df_outage[df_outage["Unnamed: 0"]=="South"].sum()
                    sum_miso = df_outage[df_outage["Unnamed: 0"]=="MISO"].sum()
                    df_sum_data_day =  pd.DataFrame({'Outage_North': [sum_north.iloc[index_day]],'Outage_Central': [sum_central.iloc[index_day]],
                               'Outage_South': [sum_south.iloc[index_day]],'Outage_MISO': [sum_miso.iloc[index_day]]})
                    df_outage_sum = pd.DataFrame()
                    for i_hour in range(24):
                        df_outage_sum = pd.concat([df_sum_data_day, df_outage_sum], ignore_index = False)
                    data_array.append(2)
            
                except:
                    print("Can not find: ", YYYYMMDD)
                    intial_date = date(int(date_str[0]), int(date_str[1]), int(date_str[2]))
                    day_i = 0
                    #day_i = day_i + 1
                    file_date = intial_date + timedelta(days = -day_i)
                    file_date_str = str(file_date).split('-')
                    YYYYMMDD_1 = file_date_str[0]+file_date_str[1]+file_date_str[2]
                    url_try = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD_1+ '_'+variable_str
        
                    response = requests.get(url_try)
                    while response.status_code != 200:
                        file_date = intial_date + timedelta(days = -day_i)
                        file_date_str = str(file_date).split('-')
                        YYYYMMDD_1 = file_date_str[0]+file_date_str[1]+file_date_str[2]
                        url_try = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD_1 + '_' + variable_str
                        response = requests.get(url_try)
                        day_i = day_i + 1
                    #print("Found previous: ", YYYYMMDD_1)
                    #url_1_1 = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD + '_mom.xlsx'
                    #df = pd.read_excel(url_try, index_col=None, sheet_name='OUTAGE',na_values=['NA'], usecols="A,B,C,D,E,F,G,H,I")
                    header = 6
                    
                    df_outage = pd.read_excel(io = url_try,index_col= None , na_values=['NA'], header=header, usecols="A,B,C,D,E,F,G,H,I",#,D
                                     sheet_name=variable_date_str,nrows = 16,engine="openpyxl")
                    index_day = day_i+1
                    print("!!!!!",index_day)
                    
                    sum_north = df_outage[df_outage["Unnamed: 0"]=="North"].sum()
                    sum_central = df_outage[df_outage["Unnamed: 0"]=="Central"].sum()
                    sum_south = df_outage[df_outage["Unnamed: 0"]=="South"].sum()
                    sum_miso = df_outage[df_outage["Unnamed: 0"]=="MISO"].sum()
                    df_sum_data_day =  pd.DataFrame({'Outage_North': [sum_north.iloc[index_day]],'Outage_Central': [sum_central.iloc[index_day]],
                               'Outage_South': [sum_south.iloc[index_day]],'Outage_MISO': [sum_miso.iloc[index_day]]})
                    df_outage_sum = pd.DataFrame()
                    for i_hour in range(24):
                        df_outage_sum = pd.concat([df_sum_data_day, df_outage_sum], ignore_index = False)
                    print(df_outage_sum)
                data_array.append(2)
                
            
            if str(day) == str(start_time):
                sum_df = df_outage_sum
            else:
                sum_df = pd.concat([sum_df, df_outage_sum], ignore_index = False)#, ignore_index = True
            url_1 = url_2
            i = i + 1
    ###
    # elif (variable_name == 'demand_forecast_hourly_zone_MISO')
    ###
    elif variable_name == 'demand_forecast_hourly_zone_MISO':
        for day in date_list:
            date_list = str(day).split('-')
            YYYYMMDD = date_list[0]+date_list[1]+date_list[2]
            url = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD + '_' + variable_str
        
            df = pd.read_excel(io = url,index_col= None , na_values=['NA'], 
                               header=None, skiprows = [i for i in (range(32))], nrows = 24).drop([3,5,7,9,11,13,15], axis=1)#, usecols=["C","E","G","I","K","M","O"]
            df.rename(columns={0: 'Date', 1: 'Hour', 2: 'Zone1', 4: 'Zone2_7', 6: 'Zone3_5', 8: 'Zone4', 10: 'Zone6', 12: 'Zone8_9', 14: 'MISO'}, inplace=True)#print(day)
            #print(df)
            if str(day) == str(start_time):
                sum_df = df
            else:
                sum_df = pd.concat([sum_df, df], ignore_index = True)

    ###
    # elif (variable_name == 'demand_forecast_hourly_zone_MISO')
    ###
    elif (variable_name == 'demand_forecast_hourly_regional_MISO'):
        for day in date_list:
            date_list = str(day).split('-')
            YYYYMMDD = date_list[0]+date_list[1]+date_list[2]
            url = 'https://docs.misoenergy.org/marketreports/'+ YYYYMMDD + '_' + variable_str
    
            df = pd.read_excel(io = url,index_col= None , na_values=['NA'],# North - D; Central - F; MISO - J
                               header=None, skiprows = [i for i in (range(34))], nrows = 24).drop([0, 4,6,8,10], axis=1)
            df.rename(columns={1: 'Date', 2: 'Hour', 3: 'North', 5: 'Central', 7: 'South', 9: 'MISO'}, inplace=True)
            #print(day)
            if str(day) == str(start_time):
                sum_df = df
            else:
                sum_df = pd.concat([sum_df, df], ignore_index = True)
        
    return sum_df


sum_df = miso_data_downloading(start_time, end_time, variable_name, info_dict_MISO)
print(sum_df)
# Out:
# Enter the start time(YYYY-MM-DD):
# Enter the end time(YYYY-MM-DD):
# Enter the Variable name:
#           Date  Hour  North  Central  South   MISO
# 0   01/01/2025     1  16866    33141  17769  67776
# 1   01/01/2025     2  16417    32219  17714  66350
# 2   01/01/2025     3  16139    32538  17778  66455
# 3   01/01/2025     4  15993    32668  17806  66467
# 4   01/01/2025     5  15940    32740  17835  66515
# 5   01/01/2025     6  16057    32822  17893  66772
# 6   01/01/2025     7  16262    33055  18116  67433
# 7   01/01/2025     8  16499    32680  18573  67752
# 8   01/01/2025     9  16707    33406  18814  68927
# 9   01/01/2025    10  16762    34208  18655  69625
# 10  01/01/2025    11  16883    34981  18286  70150
# 11  01/01/2025    12  17023    35510  17737  70270
# 12  01/01/2025    13  17019    35653  17120  69792
# 13  01/01/2025    14  16952    35469  16727  69148
# 14  01/01/2025    15  16784    34874  16339  67997
# 15  01/01/2025    16  16691    34952  16039  67682
# 16  01/01/2025    17  16997    35551  16197  68745
# 17  01/01/2025    18  17862    37087  16741  71690
# 18  01/01/2025    19  18983    38343  17864  75190
# 19  01/01/2025    20  19108    38146  18852  76106
# 20  01/01/2025    21  18843    37779  19224  75846
# 21  01/01/2025    22  18519    37180  19357  75056
# 22  01/01/2025    23  17989    36090  19116  73195
# 23  01/01/2025    24  17351    34868  18676  70895
# 24  01/02/2025     1  17156    35025  19186  71367
# 25  01/02/2025     2  16780    33541  18979  69300
# 26  01/02/2025     3  16546    33166  18924  68636
# 27  01/02/2025     4  16445    33062  18940  68447
# 28  01/02/2025     5  16450    33382  19130  68962
# 29  01/02/2025     6  16670    34416  19541  70627
# 30  01/02/2025     7  17215    36086  20398  73699
# 31  01/02/2025     8  18039    37827  21383  77249
# 32  01/02/2025     9  18660    38698  21713  79071
# 33  01/02/2025    10  18822    39067  21402  79291
# 34  01/02/2025    11  18872    39249  20697  78818
# 35  01/02/2025    12  18904    39135  19744  77783
# 36  01/02/2025    13  18883    38883  18808  76574
# 37  01/02/2025    14  18802    38598  18154  75554
# 38  01/02/2025    15  18675    38307  17827  74809
# 39  01/02/2025    16  18568    38118  17629  74315
# 40  01/02/2025    17  18693    38460  17690  74843
# 41  01/02/2025    18  19232    39811  18123  77166
# 42  01/02/2025    19  19956    40760  19053  79769
# 43  01/02/2025    20  19876    40377  19745  79998
# 44  01/02/2025    21  19600    39725  19794  79119
# 45  01/02/2025    22  19363    38819  19653  77835
# 46  01/02/2025    23  18959    37496  19233  75688
# 47  01/02/2025    24  18522    36134  18589  73245

# %% [markdown]
# # PJM

# %%
import urllib.request, json
import pandas as pd
from datetime import datetime, timedelta
import time
import random

start_time = input('Enter the start time(YYYY-MM-DD): ')
if len(start_time) < 1:
    start_time = '2025-01-01'

end_time = input('Enter the end time(YYYY-MM-DD): ')
if len(end_time) < 1:
    end_time = '2025-01-02'

variable_name = input('Enter the Variable name: ')
if len(variable_name) < 1:
    variable_name = 'solar_forecast_hourly_PJM'

info_dict_PJM = {'solar_forecast_5min_PJM':{'variable_str':'five_min_solar_power_forecast','variable_date_str':'datetime_beginning_ept'},
    'solar_forecast_hourly_PJM':{'variable_str':'hourly_solar_power_forecast','variable_date_str':'datetime_beginning_ept'},
    'wind_forecast_5min_PJM':{'variable_str':'five_min_wind_power_forecast','variable_date_str':'datetime_beginning_ept'},
    'wind_forecast_hourly_PJM':{'variable_str':'hourly_wind_power_forecast','variable_date_str':'datetime_beginning_ept'},
    'outage_forecast_daily_PJM':{'variable_str':'frcstd_gen_outages','variable_date_str':'forecast_date'},
    'demand_forecast_hourly_PJM':{'variable_str':'load_frcstd_hist','variable_date_str':'datetime_beginning_ept'},
    'DA_LMP_PJM':{'variable_str':'da_hrl_lmps','variable_date_str':'datetime_beginning_ept'},
    'RT_LMP_PJM':{'variable_str':'rt_fivemin_mnt_lmps','variable_date_str':'datetime_beginning_ept'},
    }

def pjm_data_downloading(start_time, end_time, variable_name, info_dict_PJM):
    variable_str = info_dict_PJM[variable_name]['variable_str']
    variable_date_str = info_dict_PJM[variable_name]['variable_date_str']
    PJM_no_hist_variable_list = ['solar_forecast_5min_PJM','solar_forecast_hourly_PJM','wind_forecast_5min_PJM','wind_forecast_hourly_PJM']
    
    hdr ={
            # Request headers
            'Cache-Control': 'no-cache',
            'Ocp-Apim-Subscription-Key': '336423db3cd243a3841d772330f22cc7',
            }
    urls = []
    df_results = pd.DataFrame()
    
    ####################################
    if variable_name in PJM_no_hist_variable_list:
        print("Note: PJM does not store renewable forecast data beyond 30 days, the function will turn to download last 30 days' data")
        current_date = datetime.now()# Get the current date
        formatted_current_date = datetime.now().strftime("%Y-%m-%d")
        formatted_30_days_ago_date = (datetime.now()-timedelta(days=30)).strftime("%Y-%m-%d")
        if (variable_name == 'solar_forecast_5min_PJM' or variable_name == 'wind_forecast_5min_PJM'):
        ## 5 min level data beyond the capacity of single PJM API call, turn it to mutiple API call
            try:
                for iter_days in range(9):
                    start_time_iter = (current_date-timedelta(days=iter_days*3+3)).strftime("%Y-%m-%d")
                    end_time_iter = (current_date-timedelta(days=iter_days*3)).strftime("%Y-%m-%d")
                    url = ("https://api.pjm.com/api/v1/" + variable_str +
                           "?rowCount=50000&order=Asc&startRow=1&" + variable_date_str + 
                           "=" + start_time_iter + "%2000:00%20to%20" + end_time_iter + "%2000:00")
                    urls.append(url)
            
            except Exception as e:
                print(e)
        else:
            try:
                start_time_iter = current_date
                url = ("https://api.pjm.com/api/v1/" + variable_str +
                       "?rowCount=50000&order=Asc&startRow=1&" + variable_date_str + 
                       "=" + formatted_30_days_ago_date + "%2000:00%20to%20" + formatted_current_date + "%2000:00")
                urls.append(url)
            
            except Exception as e:
                print(e)
    ####################################       
    elif variable_name == 'outage_forecast_daily_PJM':
        try:
            url = ("https://api.pjm.com/api/v1/" + variable_str +
                   "?rowCount=50000&order=Asc&startRow=1&" + variable_date_str + 
                   "=" + start_time)
            
            urls.append(url)
        except Exception as e:
            print(e)
    ####################################
    else:  
        try:
            url = ("https://api.pjm.com/api/v1/" + variable_str +
                   "?rowCount=50000&order=Asc&startRow=1&" + variable_date_str + 
                   "=" + start_time + "%2000:00%20to%20" + end_time + "%2000:00")
            
            urls.append(url)
        except Exception as e:
            print(e)
    ####################################
    for i_url, url in enumerate(urls):
        req = urllib.request.Request(url, headers=hdr)
        req.get_method = lambda: 'GET'
        response = urllib.request.urlopen(req)
        print(response.getcode())
        results = response.read()
        json_data = json.loads(results.decode('utf-8'))
        print(url)
        df_results_1 = pd.DataFrame(json_data['items'])
        print(df_results_1)
        if i_url % 4 == 0 and i_url!=0:#the whole loop used to reset the PJM api call
            time.sleep(random.randint(1, 5)) #take a sleep to make it like human bechavior
            url_random = "https://api.pjm.com/api/v1/load_frcstd_hist?rowCount=50000&order=Asc&startRow=1"
            req = urllib.request.Request(url_random, headers=hdr)#take a random api call to reset the count
            req.get_method = lambda: 'GET'
            response = urllib.request.urlopen(req)
            print('Reset the api count')
        df_results = pd.concat([df_results_1,df_results], ignore_index=True)
    #print(df_results)
    
    return df_results
df_results = pjm_data_downloading(start_time, end_time, variable_name, info_dict_PJM)
print(df_results)
# Out:
# Enter the start time(YYYY-MM-DD):
# Enter the end time(YYYY-MM-DD):
# Enter the Variable name:
# Note: PJM does not store renewable forecast data beyond 30 days, the function will turn to download last 30 days' data
# 200
# https://api.pjm.com/api/v1/hourly_solar_power_forecast?rowCount=50000&order=Asc&startRow=1&datetime_beginning_ept=2025-09-03%2000:00%20to%202025-10-03%2000:00
#           evaluated_at_utc     evaluated_at_ept datetime_beginning_utc  \
# 0      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T00:00:00
# 1      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T01:00:00
# 2      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T02:00:00
# 3      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T03:00:00
# 4      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T04:00:00
# ...                    ...                  ...                    ...
# 32467  2025-10-03T02:00:00  2025-10-02T22:00:00    2025-10-03T03:00:00
# 32468  2025-10-03T02:00:00  2025-10-02T22:00:00    2025-10-03T04:00:00
# 32469  2025-10-03T03:00:00  2025-10-02T23:00:00    2025-10-03T03:00:00
# 32470  2025-10-03T03:00:00  2025-10-02T23:00:00    2025-10-03T04:00:00
# 32471  2025-10-03T04:00:00  2025-10-03T00:00:00    2025-10-03T04:00:00
#
#       datetime_beginning_ept  datetime_ending_utc  datetime_ending_ept  \
# 0        2025-09-03T20:00:00  2025-09-04T01:00:00  2025-09-03T21:00:00
# 1        2025-09-03T21:00:00  2025-09-04T02:00:00  2025-09-03T22:00:00
# 2        2025-09-03T22:00:00  2025-09-04T03:00:00  2025-09-03T23:00:00
# 3        2025-09-03T23:00:00  2025-09-04T04:00:00  2025-09-04T00:00:00
# 4        2025-09-04T00:00:00  2025-09-04T05:00:00  2025-09-04T01:00:00
# ...                      ...                  ...                  ...
# 32467    2025-10-02T23:00:00  2025-10-03T04:00:00  2025-10-03T00:00:00
# 32468    2025-10-03T00:00:00  2025-10-03T05:00:00  2025-10-03T01:00:00
# 32469    2025-10-02T23:00:00  2025-10-03T04:00:00  2025-10-03T00:00:00
# 32470    2025-10-03T00:00:00  2025-10-03T05:00:00  2025-10-03T01:00:00
# 32471    2025-10-03T00:00:00  2025-10-03T05:00:00  2025-10-03T01:00:00
#
#        solar_forecast_mwh  solar_forecast_btm_mwh
# 0                   1.885                     0.0
# 1                   0.000                     0.0
# 2                   0.000                     0.0
# 3                   0.000                     0.0
# 4                   0.000                     0.0
# ...                   ...                     ...
# 32467               0.000                     0.0
# 32468               0.000                     0.0
# 32469               0.000                     0.0
# 32470               0.000                     0.0
# 32471               0.000                     0.0
#
# [32472 rows x 8 columns]
#           evaluated_at_utc     evaluated_at_ept datetime_beginning_utc  \
# 0      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T00:00:00
# 1      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T01:00:00
# 2      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T02:00:00
# 3      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T03:00:00
# 4      2025-09-04T00:00:00  2025-09-03T20:00:00    2025-09-04T04:00:00
# ...                    ...                  ...                    ...
# 32467  2025-10-03T02:00:00  2025-10-02T22:00:00    2025-10-03T03:00:00
# 32468  2025-10-03T02:00:00  2025-10-02T22:00:00    2025-10-03T04:00:00
# 32469  2025-10-03T03:00:00  2025-10-02T23:00:00    2025-10-03T03:00:00
# 32470  2025-10-03T03:00:00  2025-10-02T23:00:00    2025-10-03T04:00:00
# 32471  2025-10-03T04:00:00  2025-10-03T00:00:00    2025-10-03T04:00:00
#
#       datetime_beginning_ept  datetime_ending_utc  datetime_ending_ept  \
# 0        2025-09-03T20:00:00  2025-09-04T01:00:00  2025-09-03T21:00:00
# 1        2025-09-03T21:00:00  2025-09-04T02:00:00  2025-09-03T22:00:00
# 2        2025-09-03T22:00:00  2025-09-04T03:00:00  2025-09-03T23:00:00
# 3        2025-09-03T23:00:00  2025-09-04T04:00:00  2025-09-04T00:00:00
# 4        2025-09-04T00:00:00  2025-09-04T05:00:00  2025-09-04T01:00:00
# ...                      ...                  ...                  ...
# 32467    2025-10-02T23:00:00  2025-10-03T04:00:00  2025-10-03T00:00:00
# 32468    2025-10-03T00:00:00  2025-10-03T05:00:00  2025-10-03T01:00:00
# 32469    2025-10-02T23:00:00  2025-10-03T04:00:00  2025-10-03T00:00:00
# 32470    2025-10-03T00:00:00  2025-10-03T05:00:00  2025-10-03T01:00:00
# 32471    2025-10-03T00:00:00  2025-10-03T05:00:00  2025-10-03T01:00:00
#
#        solar_forecast_mwh  solar_forecast_btm_mwh
# 0                   1.885                     0.0
# 1                   0.000                     0.0
# 2                   0.000                     0.0
# 3                   0.000                     0.0
# 4                   0.000                     0.0
# ...                   ...                     ...
# 32467               0.000                     0.0
# 32468               0.000                     0.0
# 32469               0.000                     0.0
# 32470               0.000                     0.0
# 32471               0.000                     0.0
#
# [32472 rows x 8 columns]

# %% [markdown]
# # National Weather Service

# %%
import numpy as np
import http.client
from urllib.parse import urlparse
variable_name = input('Enter the Variable Name (string): ')
if len(variable_name) < 1:
    variable_name = 'Temp'

year_str = input('Enter the year (string): ')
if len(year_str) < 1:
    year_str = '2024'

info_dict_NWS = {'Temp':{'variable_str':'temp','file_str': "YEUZ98_KWBN_"},
    'DewPoint':{'variable_str':'td','file_str': "YFUZ98_KWBN_"},
    'WindDirection':{'variable_str':'wdir','file_str': "YBUZ98_KWBN_"},
    'WindSpeed':{'variable_str':'wspd','file_str': "YCUZ98_KWBN_"},
    'SkyCover':{'variable_str':'sky','file_str': "YAUZ98_KWBN_"},
    'RelativeHumidity':{'variable_str':'rhm','file_str': "YRUZ98_KWBN_"},
    'ApparentTemp':{'variable_str':'apt','file_str': "YTUZ98_KWBN_"},
    }

#variable_str = info_dict_NWS[variable_name]['variable_str']
#path_str = "https://noaa-ndfd-pds.s3.amazonaws.com/wmo/"+ variable_str + "/"
#file_str = info_dict_NWS[variable_name]['file_str']

def check_link_exists(url):
    try:
        parsed_url = urlparse(url)
        conn = http.client.HTTPSConnection(parsed_url.netloc)
        conn.request("HEAD", parsed_url.path)
        response = conn.getresponse()
        return response.status == 200
    except Exception as e:
        print(f"Error: {e}")
        return False

def check_file_name_previous(path_str, file_str,time_str, year_str, month_str, day_str, hour_int):#Used if the current hour's file is not exist
    file_hour_index = 0
    mins = 0
    result = False
    hour_delta = 1
    url_index = (path_str + time_str + file_str + year_str 
                     + month_str + day_str + str(hour_int-hour_delta))
    while result != True:
        if mins>= 60:
            mins = 0
            hour_delta = hour_delta + 1
            hour_idx = hour_int-hour_delta
            url_index = (path_str + time_str + file_str + year_str
                     + month_str + day_str + str(hour_idx))
            #print("error")
            #break
        if mins < 10:
            mins_str = "0"+ str(mins)
        else:
            mins_str = str(mins)
        url = url_index + mins_str
        result = check_link_exists(url)
        mins = mins + 1
    file_exist_url = url_index + mins_str#str(mins-1)
    return file_exist_url, hour_delta

def check_file_name(path_str, file_str, time_str, year_str, month_str, day_str, hour_int):
    file_hour_index = 0
    mins = 0
    result = False
    url_index = (path_str + time_str + file_str + year_str 
                     + month_str + day_str + str(hour_int))
    
    while result != True:
        if mins>= 60:
            print("error:current hour's weather not availible")
            url_previous, file_hour_index = check_file_name_previous(path_str, file_str, time_str, year_str, month_str, day_str, hour_int)
            #url_previous 
            file_exist_url = url_previous #url_index + str(mins-1)
            return file_exist_url, file_hour_index
            break
        if mins < 10:
            mins_str = "0"+ str(mins)
        else:
            mins_str = str(mins)
        url = url_index + mins_str
        result = check_link_exists(url)
        mins = mins + 1
    file_exist_url = url_index + mins_str#str(mins-1)
    return file_exist_url, file_hour_index
#print(check_file_name(url_index))


def download_links_list_generation(info_dict,variable_name_str,hour_int,year_str):
    
    '''
    info_dict: dict for the variable infomation list for 
    variable_name_str: which variable are downloading ('Temp','DewPoint','WindDirection','WindSpeed','SkyCover','RelativeHumidity','ApparentTemp')
    hour_int: which hour as the reference for the forcast scan
    year_str: which year you want downloading
    '''
    variable_str = info_dict[variable_name_str]['variable_str']
    path_str = "https://noaa-ndfd-pds.s3.amazonaws.com/wmo/"+ variable_str + "/"
    file_str = info_dict[variable_name_str]['file_str']
    url_list = []
    days_num_month = np.array([31,28,31,30,31,30,31,31,30,31,30,31])
    
    for i_month in range(12):
        for i_day in range(days_num_month[i_month]):
            if i_month <9:
                month_str = '0'+str(i_month+1)
            else:
                month_str = str(i_month+1)
            if i_day <9:
                day_str = '0'+str(i_day+1)
            else:
                day_str = str(i_day+1)
            time_str = year_str+'/'+ month_str +'/'+day_str+'/'
            #url_index = ("https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/" + time_str + "YEUZ98_KWBN_"+ year_str 
            #             + month_str + day_str + "20")
            result, file_hour_index = check_file_name(path_str, file_str,time_str, year_str, month_str, day_str, hour_int)#url_index
            print(result,file_hour_index)
            url_list.append(result)
            #print(check_file_name(url_index))
    return url_list

hour_int = 20
url_list = download_links_list_generation(info_dict_NWS,variable_name,hour_int,year_str)
print(url_list)
# Out:
# Enter the Variable Name:
# Enter the year:
# Enter the Variable name:
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/01/YEUZ98_KWBN_202401012019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/02/YEUZ98_KWBN_202401022019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/03/YEUZ98_KWBN_202401032019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/04/YEUZ98_KWBN_202401042020 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/05/YEUZ98_KWBN_202401052020 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/06/YEUZ98_KWBN_202401062019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/07/YEUZ98_KWBN_202401072020 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/08/YEUZ98_KWBN_202401082021 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/09/YEUZ98_KWBN_202401092020 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/10/YEUZ98_KWBN_202401102020 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/11/YEUZ98_KWBN_202401112024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/12/YEUZ98_KWBN_202401122023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/13/YEUZ98_KWBN_202401132025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/14/YEUZ98_KWBN_202401142023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/15/YEUZ98_KWBN_202401152024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/16/YEUZ98_KWBN_202401162024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/17/YEUZ98_KWBN_202401172024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/18/YEUZ98_KWBN_202401182021 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/19/YEUZ98_KWBN_202401192019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/20/YEUZ98_KWBN_202401202020 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/21/YEUZ98_KWBN_202401212019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/22/YEUZ98_KWBN_202401222049 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/23/YEUZ98_KWBN_202401232019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/24/YEUZ98_KWBN_202401242020 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/25/YEUZ98_KWBN_202401252019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/26/YEUZ98_KWBN_202401262023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/27/YEUZ98_KWBN_202401272025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/28/YEUZ98_KWBN_202401282024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/29/YEUZ98_KWBN_202401292023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/30/YEUZ98_KWBN_202401302024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/31/YEUZ98_KWBN_202401312026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/01/YEUZ98_KWBN_202402012023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/02/YEUZ98_KWBN_202402022023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/03/YEUZ98_KWBN_202402032026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/04/YEUZ98_KWBN_202402042024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/05/YEUZ98_KWBN_202402052025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/06/YEUZ98_KWBN_202402062026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/07/YEUZ98_KWBN_202402072025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/08/YEUZ98_KWBN_202402082023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/09/YEUZ98_KWBN_202402092023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/10/YEUZ98_KWBN_202402102024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/11/YEUZ98_KWBN_202402112023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/12/YEUZ98_KWBN_202402122023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/13/YEUZ98_KWBN_202402132025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/14/YEUZ98_KWBN_202402142026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/15/YEUZ98_KWBN_202402152024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/16/YEUZ98_KWBN_202402162025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/17/YEUZ98_KWBN_202402172024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/18/YEUZ98_KWBN_202402182024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/19/YEUZ98_KWBN_202402192025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/20/YEUZ98_KWBN_202402202024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/21/YEUZ98_KWBN_202402212023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/22/YEUZ98_KWBN_202402222024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/23/YEUZ98_KWBN_202402232018 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/24/YEUZ98_KWBN_202402242025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/25/YEUZ98_KWBN_202402252024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/26/YEUZ98_KWBN_202402262018 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/27/YEUZ98_KWBN_202402272025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/28/YEUZ98_KWBN_202402282024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/01/YEUZ98_KWBN_202403012025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/02/YEUZ98_KWBN_202403022024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/03/YEUZ98_KWBN_202403032026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/04/YEUZ98_KWBN_202403042052 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/05/YEUZ98_KWBN_202403052025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/06/YEUZ98_KWBN_202403062025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/07/YEUZ98_KWBN_202403072023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/08/YEUZ98_KWBN_202403082025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/09/YEUZ98_KWBN_202403092027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/10/YEUZ98_KWBN_202403102023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/11/YEUZ98_KWBN_202403112024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/12/YEUZ98_KWBN_202403122023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/13/YEUZ98_KWBN_202403132025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/14/YEUZ98_KWBN_202403142023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/15/YEUZ98_KWBN_202403152023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/16/YEUZ98_KWBN_202403162022 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/17/YEUZ98_KWBN_202403172025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/18/YEUZ98_KWBN_202403182024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/19/YEUZ98_KWBN_202403192023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/20/YEUZ98_KWBN_202403202025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/21/YEUZ98_KWBN_202403212026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/22/YEUZ98_KWBN_202403222024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/23/YEUZ98_KWBN_202403232025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/24/YEUZ98_KWBN_202403242024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/25/YEUZ98_KWBN_202403252025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/26/YEUZ98_KWBN_202403262024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/27/YEUZ98_KWBN_202403272024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/28/YEUZ98_KWBN_202403282023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/29/YEUZ98_KWBN_202403292027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/30/YEUZ98_KWBN_202403302025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/03/31/YEUZ98_KWBN_202403312025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/01/YEUZ98_KWBN_202404012027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/02/YEUZ98_KWBN_202404022027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/03/YEUZ98_KWBN_202404032027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/04/YEUZ98_KWBN_202404042028 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/05/YEUZ98_KWBN_202404052025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/06/YEUZ98_KWBN_202404062025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/07/YEUZ98_KWBN_202404072026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/08/YEUZ98_KWBN_202404082026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/09/YEUZ98_KWBN_202404092027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/10/YEUZ98_KWBN_202404102027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/11/YEUZ98_KWBN_202404112030 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/12/YEUZ98_KWBN_202404122027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/13/YEUZ98_KWBN_202404132025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/14/YEUZ98_KWBN_202404142027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/15/YEUZ98_KWBN_202404152027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/16/YEUZ98_KWBN_202404162019 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/17/YEUZ98_KWBN_202404172025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/18/YEUZ98_KWBN_202404182025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/19/YEUZ98_KWBN_202404192023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/20/YEUZ98_KWBN_202404202024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/21/YEUZ98_KWBN_202404212024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/22/YEUZ98_KWBN_202404222025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/23/YEUZ98_KWBN_202404232024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/24/YEUZ98_KWBN_202404242025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/25/YEUZ98_KWBN_202404252024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/26/YEUZ98_KWBN_202404262024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/27/YEUZ98_KWBN_202404272023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/28/YEUZ98_KWBN_202404282023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/29/YEUZ98_KWBN_202404292023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/04/30/YEUZ98_KWBN_202404302024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/01/YEUZ98_KWBN_202405012024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/02/YEUZ98_KWBN_202405022025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/03/YEUZ98_KWBN_202405032025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/04/YEUZ98_KWBN_202405042024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/05/YEUZ98_KWBN_202405052024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/06/YEUZ98_KWBN_202405062016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/07/YEUZ98_KWBN_202405072016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/08/YEUZ98_KWBN_202405082022 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/09/YEUZ98_KWBN_202405092023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/10/YEUZ98_KWBN_202405102024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/11/YEUZ98_KWBN_202405112023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/12/YEUZ98_KWBN_202405122023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/13/YEUZ98_KWBN_202405132027 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/14/YEUZ98_KWBN_202405142023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/15/YEUZ98_KWBN_202405152023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/16/YEUZ98_KWBN_202405162023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/17/YEUZ98_KWBN_202405172024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/18/YEUZ98_KWBN_202405182025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/19/YEUZ98_KWBN_202405192024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/20/YEUZ98_KWBN_202405202026 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/21/YEUZ98_KWBN_202405212028 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/22/YEUZ98_KWBN_202405222025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/23/YEUZ98_KWBN_202405232023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/24/YEUZ98_KWBN_202405242023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/25/YEUZ98_KWBN_202405252025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/26/YEUZ98_KWBN_202405262025 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/27/YEUZ98_KWBN_202405272023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/28/YEUZ98_KWBN_202405282024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/29/YEUZ98_KWBN_202405292024 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/30/YEUZ98_KWBN_202405302022 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/05/31/YEUZ98_KWBN_202405312022 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/01/YEUZ98_KWBN_202406012023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/02/YEUZ98_KWBN_202406022023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/03/YEUZ98_KWBN_202406032022 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/04/YEUZ98_KWBN_202406042023 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/05/YEUZ98_KWBN_202406052016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/06/YEUZ98_KWBN_202406062016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/07/YEUZ98_KWBN_202406072016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/08/YEUZ98_KWBN_202406082016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/09/YEUZ98_KWBN_202406092016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/10/YEUZ98_KWBN_202406102016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/11/YEUZ98_KWBN_202406112016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/12/YEUZ98_KWBN_202406122016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/13/YEUZ98_KWBN_202406132016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/14/YEUZ98_KWBN_202406142016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/15/YEUZ98_KWBN_202406152016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/16/YEUZ98_KWBN_202406162016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/17/YEUZ98_KWBN_202406172016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/18/YEUZ98_KWBN_202406182016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/19/YEUZ98_KWBN_202406192016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/20/YEUZ98_KWBN_202406202016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/21/YEUZ98_KWBN_202406212016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/22/YEUZ98_KWBN_202406222016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/23/YEUZ98_KWBN_202406232016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/24/YEUZ98_KWBN_202406242016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/25/YEUZ98_KWBN_202406252016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/26/YEUZ98_KWBN_202406262016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/27/YEUZ98_KWBN_202406272016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/28/YEUZ98_KWBN_202406282016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/29/YEUZ98_KWBN_202406292016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/06/30/YEUZ98_KWBN_202406302017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/01/YEUZ98_KWBN_202407012016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/02/YEUZ98_KWBN_202407022016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/03/YEUZ98_KWBN_202407032016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/04/YEUZ98_KWBN_202407042016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/05/YEUZ98_KWBN_202407052016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/06/YEUZ98_KWBN_202407062016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/07/YEUZ98_KWBN_202407072016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/08/YEUZ98_KWBN_202407082016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/09/YEUZ98_KWBN_202407092016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/10/YEUZ98_KWBN_202407102016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/11/YEUZ98_KWBN_202407112016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/12/YEUZ98_KWBN_202407122016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/13/YEUZ98_KWBN_202407132016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/14/YEUZ98_KWBN_202407142016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/15/YEUZ98_KWBN_202407152016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/16/YEUZ98_KWBN_202407162016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/17/YEUZ98_KWBN_202407172016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/18/YEUZ98_KWBN_202407182016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/19/YEUZ98_KWBN_202407192016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/20/YEUZ98_KWBN_202407202016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/21/YEUZ98_KWBN_202407212016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/22/YEUZ98_KWBN_202407222016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/23/YEUZ98_KWBN_202407232016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/24/YEUZ98_KWBN_202407242016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/25/YEUZ98_KWBN_202407252017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/26/YEUZ98_KWBN_202407262016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/27/YEUZ98_KWBN_202407272016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/28/YEUZ98_KWBN_202407282016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/29/YEUZ98_KWBN_202407292016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/30/YEUZ98_KWBN_202407302017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/07/31/YEUZ98_KWBN_202407312016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/01/YEUZ98_KWBN_202408012016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/02/YEUZ98_KWBN_202408022016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/03/YEUZ98_KWBN_202408032016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/04/YEUZ98_KWBN_202408042017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/05/YEUZ98_KWBN_202408052017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/06/YEUZ98_KWBN_202408062017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/07/YEUZ98_KWBN_202408072016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/08/YEUZ98_KWBN_202408082017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/09/YEUZ98_KWBN_202408092016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/10/YEUZ98_KWBN_202408102016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/11/YEUZ98_KWBN_202408112016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/12/YEUZ98_KWBN_202408122016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/13/YEUZ98_KWBN_202408132016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/14/YEUZ98_KWBN_202408142016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/15/YEUZ98_KWBN_202408152017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/16/YEUZ98_KWBN_202408162016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/17/YEUZ98_KWBN_202408172016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/18/YEUZ98_KWBN_202408182016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/19/YEUZ98_KWBN_202408192016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/20/YEUZ98_KWBN_202408202016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/21/YEUZ98_KWBN_202408212016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/22/YEUZ98_KWBN_202408222016 0
# error:current hour's weather not availible
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/23/YEUZ98_KWBN_202408231616 4
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/24/YEUZ98_KWBN_202408242016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/25/YEUZ98_KWBN_202408252016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/26/YEUZ98_KWBN_202408262017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/27/YEUZ98_KWBN_202408272017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/28/YEUZ98_KWBN_202408282016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/29/YEUZ98_KWBN_202408292016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/30/YEUZ98_KWBN_202408302016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/08/31/YEUZ98_KWBN_202408312016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/01/YEUZ98_KWBN_202409012016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/02/YEUZ98_KWBN_202409022016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/03/YEUZ98_KWBN_202409032016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/04/YEUZ98_KWBN_202409042016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/05/YEUZ98_KWBN_202409052016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/06/YEUZ98_KWBN_202409062016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/07/YEUZ98_KWBN_202409072016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/08/YEUZ98_KWBN_202409082016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/09/YEUZ98_KWBN_202409092016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/10/YEUZ98_KWBN_202409102017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/11/YEUZ98_KWBN_202409112016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/12/YEUZ98_KWBN_202409122017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/13/YEUZ98_KWBN_202409132016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/14/YEUZ98_KWBN_202409142016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/15/YEUZ98_KWBN_202409152016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/16/YEUZ98_KWBN_202409162016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/17/YEUZ98_KWBN_202409172017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/18/YEUZ98_KWBN_202409182017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/19/YEUZ98_KWBN_202409192017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/20/YEUZ98_KWBN_202409202017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/21/YEUZ98_KWBN_202409212017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/22/YEUZ98_KWBN_202409222017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/23/YEUZ98_KWBN_202409232017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/24/YEUZ98_KWBN_202409242017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/25/YEUZ98_KWBN_202409252017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/26/YEUZ98_KWBN_202409262017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/27/YEUZ98_KWBN_202409272017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/28/YEUZ98_KWBN_202409282017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/29/YEUZ98_KWBN_202409292017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/09/30/YEUZ98_KWBN_202409302018 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/01/YEUZ98_KWBN_202410012017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/02/YEUZ98_KWBN_202410022017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/03/YEUZ98_KWBN_202410032017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/04/YEUZ98_KWBN_202410042017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/05/YEUZ98_KWBN_202410052017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/06/YEUZ98_KWBN_202410062017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/07/YEUZ98_KWBN_202410072017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/08/YEUZ98_KWBN_202410082017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/09/YEUZ98_KWBN_202410092017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/10/YEUZ98_KWBN_202410102048 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/11/YEUZ98_KWBN_202410112017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/12/YEUZ98_KWBN_202410122017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/13/YEUZ98_KWBN_202410132017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/14/YEUZ98_KWBN_202410142017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/15/YEUZ98_KWBN_202410152017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/16/YEUZ98_KWBN_202410162017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/17/YEUZ98_KWBN_202410172017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/18/YEUZ98_KWBN_202410182017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/19/YEUZ98_KWBN_202410192017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/20/YEUZ98_KWBN_202410202017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/21/YEUZ98_KWBN_202410212017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/22/YEUZ98_KWBN_202410222017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/23/YEUZ98_KWBN_202410232017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/24/YEUZ98_KWBN_202410242017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/25/YEUZ98_KWBN_202410252017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/26/YEUZ98_KWBN_202410262016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/27/YEUZ98_KWBN_202410272017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/28/YEUZ98_KWBN_202410282017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/29/YEUZ98_KWBN_202410292017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/30/YEUZ98_KWBN_202410302017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/10/31/YEUZ98_KWBN_202410312017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/01/YEUZ98_KWBN_202411012016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/02/YEUZ98_KWBN_202411022016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/03/YEUZ98_KWBN_202411032016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/04/YEUZ98_KWBN_202411042016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/05/YEUZ98_KWBN_202411052017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/06/YEUZ98_KWBN_202411062017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/07/YEUZ98_KWBN_202411072017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/08/YEUZ98_KWBN_202411082017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/09/YEUZ98_KWBN_202411092017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/10/YEUZ98_KWBN_202411102017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/11/YEUZ98_KWBN_202411112017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/12/YEUZ98_KWBN_202411122017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/13/YEUZ98_KWBN_202411132017 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/14/YEUZ98_KWBN_202411142016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/15/YEUZ98_KWBN_202411152016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/16/YEUZ98_KWBN_202411162016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/17/YEUZ98_KWBN_202411172016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/18/YEUZ98_KWBN_202411182016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/19/YEUZ98_KWBN_202411192016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/20/YEUZ98_KWBN_202411202016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/21/YEUZ98_KWBN_202411212016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/22/YEUZ98_KWBN_202411222016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/23/YEUZ98_KWBN_202411232016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/24/YEUZ98_KWBN_202411242016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/25/YEUZ98_KWBN_202411252016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/26/YEUZ98_KWBN_202411262016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/27/YEUZ98_KWBN_202411272016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/28/YEUZ98_KWBN_202411282016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/29/YEUZ98_KWBN_202411292016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/11/30/YEUZ98_KWBN_202411302016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/01/YEUZ98_KWBN_202412012016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/02/YEUZ98_KWBN_202412022016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/03/YEUZ98_KWBN_202412032016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/04/YEUZ98_KWBN_202412042016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/05/YEUZ98_KWBN_202412052016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/06/YEUZ98_KWBN_202412062016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/07/YEUZ98_KWBN_202412072016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/08/YEUZ98_KWBN_202412082016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/09/YEUZ98_KWBN_202412092016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/10/YEUZ98_KWBN_202412102016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/11/YEUZ98_KWBN_202412112016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/12/YEUZ98_KWBN_202412122016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/13/YEUZ98_KWBN_202412132016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/14/YEUZ98_KWBN_202412142016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/15/YEUZ98_KWBN_202412152016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/16/YEUZ98_KWBN_202412162016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/17/YEUZ98_KWBN_202412172016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/18/YEUZ98_KWBN_202412182016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/19/YEUZ98_KWBN_202412192016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/20/YEUZ98_KWBN_202412202016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/21/YEUZ98_KWBN_202412212016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/22/YEUZ98_KWBN_202412222016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/23/YEUZ98_KWBN_202412232016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/24/YEUZ98_KWBN_202412242016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/25/YEUZ98_KWBN_202412252016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/26/YEUZ98_KWBN_202412262016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/27/YEUZ98_KWBN_202412272016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/28/YEUZ98_KWBN_202412282016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/29/YEUZ98_KWBN_202412292016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/30/YEUZ98_KWBN_202412302016 0
# https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/12/31/YEUZ98_KWBN_202412312016 0
# ['https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/01/YEUZ98_KWBN_202401012019', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/02/YEUZ98_KWBN_202401022019', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/03/YEUZ98_KWBN_202401032019', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/04/YEUZ98_KWBN_202401042020', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/05/YEUZ98_KWBN_202401052020', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/06/YEUZ98_KWBN_202401062019', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/07/YEUZ98_KWBN_202401072020', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/08/YEUZ98_KWBN_202401082021', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/09/YEUZ98_KWBN_202401092020', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/10/YEUZ98_KWBN_202401102020', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/11/YEUZ98_KWBN_202401112024', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/12/YEUZ98_KWBN_202401122023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/13/YEUZ98_KWBN_202401132025', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/14/YEUZ98_KWBN_202401142023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/15/YEUZ98_KWBN_202401152024', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/16/YEUZ98_KWBN_202401162024', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/17/YEUZ98_KWBN_202401172024', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/18/YEUZ98_KWBN_202401182021', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/19/YEUZ98_KWBN_202401192019', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/20/YEUZ98_KWBN_202401202020', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/21/YEUZ98_KWBN_202401212019', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/22/YEUZ98_KWBN_202401222049', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/23/YEUZ98_KWBN_202401232019', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/24/YEUZ98_KWBN_202401242020', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/25/YEUZ98_KWBN_202401252019', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/26/YEUZ98_KWBN_202401262023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/27/YEUZ98_KWBN_202401272025', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/28/YEUZ98_KWBN_202401282024', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/29/YEUZ98_KWBN_202401292023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/30/YEUZ98_KWBN_202401302024', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/01/31/YEUZ98_KWBN_202401312026', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/01/YEUZ98_KWBN_202402012023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/02/YEUZ98_KWBN_202402022023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/03/YEUZ98_KWBN_202402032026', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/04/YEUZ98_KWBN_202402042024', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/05/YEUZ98_KWBN_202402052025', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/06/YEUZ98_KWBN_202402062026', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/07/YEUZ98_KWBN_202402072025', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/08/YEUZ98_KWBN_202402082023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/09/YEUZ98_KWBN_202402092023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/10/YEUZ98_KWBN_202402102024', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/11/YEUZ98_KWBN_202402112023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/12/YEUZ98_KWBN_202402122023', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/13/YEUZ98_KWBN_202402132025', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/14/YEUZ98_KWBN_202402142026', 'https://noaa-ndfd-pds.s3.amazonaws.com/wmo/temp/2024/02/15/YEUZ98_KWBN_202402152024 ...

# %%
import os
import requests

# Example usage
def download_files(url_list, save_path):
    if not os.path.exists(save_path):
        os.makedirs(save_path)
    
    for url in url_list:
        try:
            response = requests.get(url)
            response.raise_for_status()  # Check if the request was successful
            file_name = os.path.join(save_path, url.split('/')[-1])
            with open(file_name, 'wb') as file:
                file.write(response.content)
            print(f"Downloaded: {file_name}")
        except requests.exceptions.RequestException as e:
            print(f"Failed to download {url}: {e}")


save_directory = "H:/NOAA/WeatherForcast/"+ variable_str + "/"

download_files(url_list, save_directory)
